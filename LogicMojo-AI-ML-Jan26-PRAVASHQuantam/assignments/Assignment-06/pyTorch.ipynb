# %%
import torch
import numpy as np

# %%
scalar = torch.tensor(42)
vector = torch.tensor([1.0, 2.0, 3.0])
matrix = torch.tensor([[1, 2], [3, 4]])

# %%
scalar
# Out:
# tensor(42)

# %%
vector
# Out:
# tensor([1., 2., 3.])

# %%
matrix
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
print(vector.shape, vector.dtype)
print(matrix.dtype)
# Out:
# torch.Size([3]) torch.float32
# torch.int64

# %%
rand_weight = torch.randn(3, 4)
zeroes = torch.zeros(2,2)
ones = torch.ones(2,2)
eye = torch.eye(3)
arange = torch.arange(0, 10, step=2)
rand = torch.rand(2, 3)
lin = torch.linspace(0, 1, steps=5)

# %%
rand_weight
# Out:
# tensor([[ 1.7401,  0.6662, -0.6616,  0.6315],
#         [ 0.7910,  0.2091, -1.5020,  0.0405],
#         [ 0.3107,  0.0653, -0.9737,  0.0619]])

# %%
zeroes
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %%
ones
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
eye
# Out:
# tensor([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])

# %%
arange
# Out:
# tensor([0, 2, 4, 6, 8])

# %%
lin
# Out:
# tensor([0.0000, 0.2500, 0.5000, 0.7500, 1.0000])

# %%
rand
# Out:
# tensor([[0.2268, 0.7959, 0.4998],
#         [0.3956, 0.6811, 0.7586]])

# %%
np_arr = np.array([1.0, 2.0, 3.0])
np_arr
# Out:
# array([1., 2., 3.])

# %%
t = torch.from_numpy(np_arr)
t
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
back = t.numpy()
back
# Out:
# array([1., 2., 3.])

# %%
t[0] = 99.0

# %%
np_arr
# Out:
# array([99.,  2.,  3.])

# %%
A = torch.tensor([[1.0,2.0] , [3.0,4.0]])
B= torch.tensor([[1.0,2.0],
                 [3.0,4.0]])

# %%
C = A@B
C
# Out:
# tensor([[ 7., 10.],
#         [15., 22.]])

# %%
X = torch.tensor([
    [10, 11, 12],
    [20, 21, 22],
    [30, 31, 32]
])

print(X[0])
print(X[:, 1])
print(X[1:, :2])
# Out:
# tensor([10, 11, 12])
# tensor([11, 21, 31])
# tensor([[20, 21],
#         [30, 31]])

# %%
x = torch.tensor([1, -2, 3, -4, 5])
mask = x > 0
print(mask)
print(x[mask])
# Out:
# tensor([ True, False,  True, False,  True])
# tensor([1, 3, 5])
